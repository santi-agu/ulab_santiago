# %% [markdown]
# # HW 11 - Fall Semester Review
# ULAB - Physics and Astronomy Division \
# Due **Sunday, February 2nd, 2025 at 11:59pm** on Gradescope
#
# To prepare for next week’s homework, where we’ll explore exoplanets using **pandas**, this assignment will review fundamental Python concepts within the same theme.

# %% [markdown]
# ## 0 Academic Integrity
# Please type the following message in the cell below as a comment. Sign with your name.
#
# ------
# **I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.**
#
# ------

# %%
# I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.
# -Santiago Agudelo

# %% [markdown]
# ## 1 Functions
# **Orbital Periods and Kepler's Third Law** \
# Kepler's Third Law states that the square of the orbital period $T$ (in years) of a planet is proportional to the cube of the semi-major axis $a$ (in astronomical units, AU):
#
# $$
# T^2 = a^3
# $$
#
# Write a **function** that calculates the orbital period $T$ given the semi-major axis $a$. (So, you can assume that $T = \sqrt{a^3}$.)

# %%
def calculate_period(axis):
    # Given the semi-major axis of a planet a (in AU), calculates and returns its orbiral period (in years)
    # Uses the equation T^2 = a^3
    period = axis ** 1.5
    return period

# %% [markdown]
# Call your function with the following values:
# * `planet_a` $ = 0.5\,\text{AU}$
# * `planet_b` $ = 1.0\,\text{AU}$
# * `planet_c` $ = 1.5\,\text{AU}$

# %%
planet_a = 0.5
planet_b = 1.0
planet_c = 1.5

print(calculate_period(planet_a))
print(calculate_period(planet_b))
print(calculate_period(planet_c))
# Out:
# 0.3535533905932738
# 1.0
# 1.8371173070873836

# %% [markdown]
# Import `numpy` in the cell below.

# %%
import numpy as np

# %% [markdown]
# How many times do you need to call numpy in a jupyter notebook? Why?

# %%
# You need to import numpy (I think that's what's being asked) only once in jupyter notebooks. 
# This is because importing a library essentially stores all of its contents into the text editor, so importing it more than once is redundant.

# %% [markdown]
# Rewrite your **function** from above with a `numpy` function.

# %%
def calculate_period_with_numpy(axis):
    # Given the semi-major axis of a planet a (in AU), calculates and returns its orbiral period (in years)
    # Uses the equation T^2 = a^3 and the numpy library
    period = np.power(axis, 1.5)
    return period

# %% [markdown]
# Import the `time` package in the cell below.

# %%
import time

# %% [markdown]
# Call both of your functions in the cell below with ($a$ = 5). Time how long it takes each of your functions to run. **DO NOT REWRITE THEM!**

# %%
start = time.time()
calculate_period(5)
end = time.time()
print(end - start)

start = time.time()
calculate_period_with_numpy(5)
end = time.time()
print(end - start)
# Out:
# 4.291534423828125e-05
# 5.984306335449219e-05

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# The function that does not rely on numpy is a bit faster. I assume this is because numpy's implementation is more complex,
# since its methods are meant to handle entire arrays of numbers. Having more complex code generally means the code runs slower.

# %% [markdown]
# Define a **list** in the cell below that contains a least 1,000,000 semi-major axis values.

# %%
axis_list = []
for i in range(1000000):
    axis_list.append( i ** 2 )

# %% [markdown]
# With a **for** loop. Time each of your functions again with this new list.

# %%
start = time.time()
for i in range(1000000):
    calculate_period(axis_list[i])
end = time.time()
print(end - start)

start = time.time()
calculate_period_with_numpy(axis_list)
end = time.time()
print(end - start)
# Out:
# 0.11036896705627441
# 0.029714107513427734

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# The function with numpy is a bit faster, probably because numpy has some sort of implementation that makes it very efficient
# when dealing with large amounts of data. This shows that numpy is faster when we have large arrays, but it is not better
# to use it when we only need to do math on one number.

# %% [markdown]
# ## 2 Indexing + Conditionals
#
# You are provided with a list of exoplanet radii (in Earth radii) and their equilibrium temperatures (in Kelvin):
#
# `radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]` \
# `temperatures = [300, 400, 350, 280, 500, 450]`

# %% [markdown]
# Write a loop to filter and print the radii of planets with temperatures below 350 K.

# %%
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]
for i in range(len(radii)):
    if temperatures[i] < 350:
        print(radii[i])
# Out:
# 1.2
# 2.0

# %% [markdown]
# Use list slicing to extract and print the radii of the first three planets.

# %%
print(radii[:3])
# Out:
# [1.2, 0.8, 1.5]

# %% [markdown]
# Turn the radii and temperatures data into a dictionary.

# %%
data_dictionary = {}
for i in range(len(radii)):
    data_dictionary[radii[i]] = temperatures[i]

# %% [markdown]
# Give each of the planets in your dictionary a name.

# %%
names = ["Megatron", "Poo", "Notearth", "Chungus", "Earth", "Lil Guy"]

# %% [markdown]
# Create a new dictionary of planets with radii between 1.0 and 2.0 Earth radii (inclusive).

# %%
smaller_radii_dict = {}
index = 0
for key in data_dictionary.keys():
    if(1 <= key <= 2):
        smaller_radii_dict[names[index]] = key
    index += 1
print(smaller_radii_dict)
# Out:
# {'Megatron': 1.2, 'Notearth': 1.5, 'Chungus': 2.0, 'Earth': 1.0}

# %% [markdown]
# ## 3 NumPy
# With your 1,000,000 semi-major axes list from Problem 1, convert it to a `numpy` array.

# %%
arr = np.array(axis_list)

# %% [markdown]
# With `numpy` find the mean, median, minimum and maximum.

# %%
mean = np.mean(arr)
print(f"Mean: {mean}")
median = np.median(arr)
print(f"Median: {median}")
minimum = np.min(arr)
print(f"Minimum: {minimum}")
maximum = np.max(arr)
print(f"Maximum: {maximum}")
# Out:
# Mean: 333332833333.50006
# Median: 249999500000.5
# Minimum: 0
# Maximum: 999998000001

# %% [markdown]
# Google another `numpy` function and apply it to your data. Explain what it does in a comment.

# %%
split_arr = np.hsplit(arr, 2)
# splits the array into two subarrays, and returns an array that contains both subarrays

# %% [markdown]
# Turn the radii and temperatures from Problem 2 into a multi-dimensional array.

# %%
multi_arr = np.array([radii, temperatures])
print(multi_arr)
# Out:
# [[  1.2   0.8   1.5   2.    1.    0.6]
#  [300.  400.  350.  280.  500.  450. ]]

# %% [markdown]
# Use a for loop to print the value on the second row, third column.

# %%
for i in range(2):
    for j in range(3):
        if i == 1 and j == 2:
            print(multi_arr[i][j])
# couldn't I just do 'print(multi_arr[1][2])'?
# Out:
# 350.0

# %% [markdown]
# Use a `numpy` arrive to print the value on the second row, third column.

# %%
# I literally don't understand what this question is asking
print(multi_arr[1][2])
# Out:
# 350.0

# %% [markdown]
# ## 4 Plotting
# Create a scatter plot of the following semi-major axes (x-axis) vs. orbital periods (y-axis). Label the axes, add a legend and add a title: "Orbital Periods of Exoplanets."
#
# `semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]`

# %%
import matplotlib.pyplot as plt

semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]
semi_major_axes = np.array(semi_major_axes)
semi_major_axes = np.sort(semi_major_axes)

periods = calculate_period_with_numpy(semi_major_axes)
plt.figure(figsize = (5, 5))
plt.plot(semi_major_axes, periods, label = "period vs semi-major axis")
plt.xlabel("x axis (semi-major axes)", fontsize = 20)
plt.ylabel("y axis (periods)", fontsize = 20)
plt.title("Orbital Periods of Exoplanets.")
plt.legend()
plt.show()

# %% [markdown]
# Create a bar plot of planet radii vs. their equilibrium temperatures. Label the axes, add a legend and add a title: "Equilibrium Temperatures vs. Radii."

# %%
radii = np.array(radii)
radii = np.sort(radii)

temperatures = np.array(temperatures)
temperatures = np.sort(temperatures)

plt.figure(figsize = (5, 5))
plt.bar(radii, temperatures, label = "temperatures vs radii")
plt.xlabel("x axis (radii)", fontsize = 20)
plt.ylabel("y axis (temperatures)", fontsize = 20)
plt.title("Equilibrium Temperatures vs. Radii.")
plt.legend()

plt.show()

# %% [markdown]
# Put the scatter plot and bar plot on the same figure (horizontally).

# %%
plt.figure(figsize = (10, 5))
plt.subplot(1, 2, 1)
plt.bar(radii, temperatures, label = "temperatures vs radii")
plt.xlabel("x axis (semi-major axes)", fontsize = 20)
plt.ylabel("y axis (periods)", fontsize = 20)
plt.title("Orbital Periods of Exoplanets.")
plt.legend()

plt.subplot(1,2, 2)
plt.plot(semi_major_axes, periods, color = 'red', label = "period vs semi-major axis")
plt.xlabel("x axis (radii)", fontsize = 20)
plt.ylabel("y axis (temperatures)", fontsize = 20)
plt.title("Equilibrium Temperatures vs. Radii.")
plt.legend()

plt.show()

# %% [markdown]
# ## 5 Modules
# Choose a function from this homework and put it into a module. Import the module with the function below. Make sure to show the output.

# %%
import period_calculator
semi_major_axes = np.array([1, 11, 2, 61, 3])
periods = period_calculator.calculate_period_with_numpy_in_module(semi_major_axes)

print(periods)
# Out:
# [  1.          36.48287269   2.82842712 476.42523023   5.19615242]
